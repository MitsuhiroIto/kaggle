# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import copy

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
print(len(train),len(test))
# Out:
# 1460 1459

# %% [markdown]
# ---

# %% [markdown]
# # 使用データの確認

# %%
train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
test.head(5)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         NaN       0      6    2010        WD         Normal
# 1        Gar2   12500      6    2010        WD         Normal
# 2         NaN       0      3    2010        WD         Normal
# 3         NaN       0      6    2010        WD         Normal
# 4         NaN       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %%
print(train['SalePrice'].describe())
train['SalePrice'].hist(bins=20, range=(0, 800000))
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# # ログ変換

# %%
train["SalePrice"] = np.log1p(train["SalePrice"])

# %% [markdown]
# # 欠陥データの確認

# %%
df_null_rate_train = pd.DataFrame(train.isnull().sum()/len(train))
df_null_rate_test = pd.DataFrame(test.isnull().sum()/len(test))
df_null_rate = pd.concat([df_null_rate_test[df_null_rate_test.values>0], df_null_rate_train[df_null_rate_train.values>0]], axis=1, sort=False).fillna(0)
df_null_rate.columns = ['test null rate', 'train null rate']
print(df_null_rate.sort_values('test null rate', ascending=False))
# Out:
#               test null rate  train null rate
# PoolQC              0.997944         0.995205
# MiscFeature         0.965045         0.963014
# Alley               0.926662         0.937671
# Fence               0.801234         0.807534
# FireplaceQu         0.500343         0.472603
# LotFrontage         0.155586         0.177397
# GarageCond          0.053461         0.055479
# GarageYrBlt         0.053461         0.055479
# GarageFinish        0.053461         0.055479
# GarageQual          0.053461         0.055479
# GarageType          0.052090         0.055479
# BsmtCond            0.030843         0.025342
# BsmtExposure        0.030158         0.026027
# BsmtQual            0.030158         0.025342
# BsmtFinType2        0.028787         0.026027
# BsmtFinType1        0.028787         0.025342
# MasVnrType          0.010966         0.005479
# MasVnrArea          0.010281         0.005479
# MSZoning            0.002742         0.000000
# Functional          0.001371         0.000000
# BsmtFullBath        0.001371         0.000000
# BsmtHalfBath        0.001371         0.000000
# Utilities           0.001371         0.000000
# KitchenQual         0.000685         0.000000
# TotalBsmtSF         0.000685         0.000000
# BsmtUnfSF           0.000685         0.000000
# GarageCars          0.000685         0.000000
# GarageArea          0.000685         0.000000
# BsmtFinSF2          0.000685         0.000000
# BsmtFinSF1          0.000685         0.000000
# Exterior2nd         0.000685         0.000000
# Exterior1st         0.000685         0.000000
# SaleType            0.000685         0.000000
# Electrical          0.000000         0.000685

# %% [markdown]
# 0.000685は欠損値1個

# %% [markdown]
# PoolQC:プールあるなし、MiscFeature:エレベーター、テニスコート等の施設、Alley: 路地のあるなし?、Fence:フェンスのあるなし、FireplaceQu:暖炉のあるなし、LotFrontage:間口の広さ

# %% [markdown]
# ---

# %% [markdown]
# # 欠陥値の補間

# %% [markdown]
# 1. ## PoolQC、Alley、MiscFeature 削除

# %%
# 最初だし、欠陥値90%以上のPoolQC、Alley、MiscFeatureは使わない
train_new0 = copy.deepcopy(train)
test_new0 = copy.deepcopy(test)

train_new0 = train_new0.drop("PoolQC", axis=1)
train_new0 = train_new0.drop("Alley", axis=1)
train_new0 = train_new0.drop("MiscFeature", axis=1)

test_new0 = test_new0.drop("PoolQC", axis=1)
test_new0 = test_new0.drop("Alley", axis=1)
test_new0 = test_new0.drop("MiscFeature", axis=1)

# %% [markdown]
# ## Fenceデータ 数値化および欠損値は0

# %%
# Fenceのデータチェック
df_fence_yes = train[train['Fence'].isnull()==False]
df_fence_no = train[train['Fence'].isnull()==True]
print(pd.concat([df_fence_no['SalePrice'].describe(),df_fence_yes['SalePrice'].describe()], axis=1, sort=False),"\n")

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6),  squeeze=False)
df_fence_no['SalePrice'].hist(bins=20,ax=axes[0, 1],range=(0, 800000))
df_fence_yes['SalePrice'].hist(bins=20,ax=axes[0, 0],range=(0, 800000))
print(train_new0['Fence'].value_counts(),"\n")
print(test_new0['Fence'].value_counts())
# Out:
#          SalePrice   SalePrice
# count  1179.000000  281.000000
# mean     12.058605   11.879106
# std       0.406170    0.333526
# min      10.471978   10.460271
# 25%      11.796229   11.719948
# 50%      12.061053   11.860062
# 75%      12.322526   12.019749
# max      13.534474   13.521141
#
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64
#
# MnPrv    172
# GdPrv     59
# GdWo      58
# MnWw       1
# Name: Fence, dtype: int64

# %%
# Fenceを五段階評価で置き換え
train_new1 = copy.deepcopy(train_new0)
test_new1 = copy.deepcopy(test_new0)

train_new1['Fence'] = train_new1['Fence'].replace({"GdPrv":4,"MnPrv":3,"GdWo":2,"MnWw":1})
train_new1['Fence'] = train_new1['Fence'].fillna(0)
print(train_new1['Fence'].value_counts(),"\n")

test_new1['Fence'] = test_new1['Fence'].replace({"GdPrv":4,"MnPrv":3,"GdWo":2,"MnWw":1})
test_new1['Fence'] = test_new1['Fence'].fillna(0)
print(test_new1['Fence'].value_counts())
# Out:
# 0.0    1179
# 3.0     157
# 4.0      59
# 2.0      54
# 1.0      11
# Name: Fence, dtype: int64
#
# 0.0    1169
# 3.0     172
# 4.0      59
# 2.0      58
# 1.0       1
# Name: Fence, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## FireplaceQu 数値化および欠損値は0

# %%
# FireplaceQuのデータチェック
df_FireplaceQu_yes = train[train['FireplaceQu'].isnull()==False]
df_FireplaceQu_no = train[train['FireplaceQu'].isnull()==True]
print(pd.concat([df_FireplaceQu_no['SalePrice'].describe(),df_FireplaceQu_yes['SalePrice'].describe()], axis=1, sort=False),"\n")

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6),  squeeze=False)
df_FireplaceQu_no['SalePrice'].hist(bins=20,ax=axes[0, 1],range=(0, 800000))
df_FireplaceQu_yes['SalePrice'].hist(bins=20,ax=axes[0, 0],range=(0, 800000))
print(train['FireplaceQu'].value_counts())
print(test['FireplaceQu'].value_counts())
# Out:
#         SalePrice   SalePrice
# count  690.000000  770.000000
# mean    11.808915   12.216847
# std      0.323420    0.360918
# min     10.460271   11.002117
# 25%     11.626263   11.976666
# 50%     11.813037   12.160034
# 75%     12.009911   12.458293
# max     12.744447   13.534474
#
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64
# Gd    364
# TA    279
# Fa     41
# Po     26
# Ex     19
# Name: FireplaceQu, dtype: int64

# %%
# FireplaceQuを6段階評価で置き換え
train_new2 = copy.deepcopy(train_new1)
test_new2 = copy.deepcopy(test_new1)

train_new2['FireplaceQu'] = train_new2['FireplaceQu'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})
train_new2['FireplaceQu'] = train_new2['FireplaceQu'].fillna(0)
print(train_new2['FireplaceQu'].value_counts(),"\n")

test_new2['FireplaceQu'] = test_new2['FireplaceQu'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})
test_new2['FireplaceQu'] = test_new2['FireplaceQu'].fillna(0)
print(test_new2['FireplaceQu'].value_counts(),"\n")
# Out:
# 0.0    690
# 4.0    380
# 3.0    313
# 2.0     33
# 5.0     24
# 1.0     20
# Name: FireplaceQu, dtype: int64
#
# 0.0    730
# 4.0    364
# 3.0    279
# 2.0     41
# 1.0     26
# 5.0     19
# Name: FireplaceQu, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## LotFrontage 回帰を使った補間

# %%
# LotFrontageのデータチェック
df_LotFrontage_yes = train_new2[train_new2['LotFrontage'].isnull()==False]
df_LotFrontage_no = train_new2[train_new2['LotFrontage'].isnull()==True]
print(pd.concat([df_LotFrontage_no['SalePrice'].describe(),df_LotFrontage_yes['SalePrice'].describe()], axis=1, sort=False))

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6),  squeeze=False)
df_LotFrontage_no['SalePrice'].hist(bins=20,ax=axes[0, 1],range=(0, 800000))
df_LotFrontage_yes['SalePrice'].hist(bins=20,ax=axes[0, 0],range=(0, 800000))
# Out:
#         SalePrice    SalePrice
# count  259.000000  1201.000000
# mean    12.062222    12.015827
# std      0.308972     0.416042
# min     11.018646    10.460271
# 25%     11.873225    11.755879
# 50%     12.057578    11.979805
# 75%     12.278398    12.271397
# max     13.053015    13.534474

# %%
train_new2.corr()['LotFrontage']

# 相関の高いLotArea、1stFlrSFで穴埋め
# Out:
# Id              -0.010601
# MSSubClass      -0.386347
# LotFrontage      1.000000
# LotArea          0.426095
# OverallQual      0.251646
# OverallCond     -0.059213
# YearBuilt        0.123349
# YearRemodAdd     0.088866
# MasVnrArea       0.193458
# BsmtFinSF1       0.233633
# BsmtFinSF2       0.049900
# BsmtUnfSF        0.132644
# TotalBsmtSF      0.392075
# 1stFlrSF         0.457181
# 2ndFlrSF         0.080177
# LowQualFinSF     0.038469
# GrLivArea        0.402797
# BsmtFullBath     0.100949
# BsmtHalfBath    -0.007234
# FullBath         0.198769
# HalfBath         0.053532
# BedroomAbvGr     0.263170
# KitchenAbvGr    -0.006069
# TotRmsAbvGrd     0.352096
# Fireplaces       0.266639
# FireplaceQu      0.245531
# GarageYrBlt      0.070250
# GarageCars       0.285691
# GarageArea       0.344997
# WoodDeckSF       0.088521
# OpenPorchSF      0.151972
# EnclosedPorch    0.010700
# 3SsnPorch        0.070029
# ScreenPorch      0.041383
# PoolArea         0.206167
# Fence            0.034139
# MiscVal          0.003368
# MoSold           0.011200
# YrSold           0.007450
# SalePrice        0.355879
# Name: LotFrontage, dtype: float64

# %%
# 相関の高いLotArea、1stFlrSFで穴埋め
from sklearn import linear_model

train_new3 = copy.deepcopy(train_new2)
test_new3 = copy.deepcopy(test_new2)

train_LotFrontage_x = df_LotFrontage_yes[['LotArea', '1stFlrSF']]
train_LotFrontage_y = df_LotFrontage_yes['LotFrontage']

clf_LotFrontage = linear_model.LinearRegression()
clf_LotFrontage.fit(train_LotFrontage_x,train_LotFrontage_y)

pd.options.mode.chained_assignment = None
for i in range(len(train_new3['LotFrontage'])):
    if train_new3.isnull().iloc[i]['LotFrontage']==True:
        train_new3['LotFrontage'][i] = int(clf_LotFrontage.predict([train_new3.iloc[i][['LotArea', '1stFlrSF']].values]))

for i in range(len(test_new3['LotFrontage'])):
    if test_new3.isnull().iloc[i]['LotFrontage']==True:
        test_new3['LotFrontage'][i] = int(clf_LotFrontage.predict([test_new3.iloc[i][['LotArea', '1stFlrSF']].values]))

# %% [markdown]
# ---

# %% [markdown]
# ## GarageQual、GarageCond 数値化および欠損値は0

# %% [markdown]
# GGarageYrBlt、GarageFinish、GarageQual、GarageCondのNAはガレージがないことを意味するので0とする

# %%
print(train_new3['GarageCond'].value_counts(),"\n")
print(test_new3['GarageCond'].value_counts(),"\n")
print(train_new3['GarageQual'].value_counts(),"\n")
print(test_new3['GarageQual'].value_counts(),"\n")
# Out:
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64
#
# TA    1328
# Fa      39
# Po       7
# Gd       6
# Ex       1
# Name: GarageCond, dtype: int64
#
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: GarageQual, dtype: int64
#
# TA    1293
# Fa      76
# Gd      10
# Po       2
# Name: GarageQual, dtype: int64

# %%
# GarageQual、GarageCondは6段階評価に直す
train_new4 = copy.deepcopy(train_new3)
test_new4 = copy.deepcopy(test_new3)

train_new4['GarageCond'] = train_new4['GarageCond'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})
train_new4['GarageCond'] = train_new4['GarageCond'].fillna(0)
print(train_new4['GarageCond'].value_counts(),"\n")

test_new4['GarageCond'] = test_new4['GarageCond'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})
test_new4['GarageCond'] = test_new4['GarageCond'].fillna(0)
print(test_new4['GarageCond'].value_counts(),"\n")

train_new4['GarageQual'] = train_new4['GarageQual'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})
train_new4['GarageQual'] = train_new4['GarageQual'].fillna(0)
print(train_new4['GarageQual'].value_counts(),"\n")

test_new4['GarageQual'] = test_new4['GarageQual'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})
test_new4['GarageQual'] = test_new4['GarageQual'].fillna(0)
print(test_new4['GarageQual'].value_counts(),"\n")
# Out:
# 3.0    1326
# 0.0      81
# 2.0      35
# 4.0       9
# 1.0       7
# 5.0       2
# Name: GarageCond, dtype: int64
#
# 3.0    1328
# 0.0      78
# 2.0      39
# 1.0       7
# 4.0       6
# 5.0       1
# Name: GarageCond, dtype: int64
#
# 3.0    1311
# 0.0      81
# 2.0      48
# 4.0      14
# 1.0       3
# 5.0       3
# Name: GarageQual, dtype: int64
#
# 3.0    1293
# 0.0      78
# 2.0      76
# 4.0      10
# 1.0       2
# Name: GarageQual, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## GarageFinish 数値化および欠損値は0

# %%
print(train_new4['GarageFinish'].value_counts(),"\n")
print(test_new4['GarageFinish'].value_counts(),"\n")
# Out:
# Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64
#
# Unf    625
# RFn    389
# Fin    367
# Name: GarageFinish, dtype: int64

# %%
# GarageFinishは4段階評価に直す
train_new5 = copy.deepcopy(train_new4)
test_new5 = copy.deepcopy(test_new4)

train_new5['GarageFinish'] = train_new5['GarageFinish'].replace({"Fin":3,"RFn":2,"Unf":1})
train_new5['GarageFinish'] = train_new5['GarageFinish'].fillna(0)
print(train_new5['GarageFinish'].value_counts(),"\n")

test_new5['GarageFinish'] = test_new5['GarageFinish'].replace({"Fin":3,"RFn":2,"Unf":1})
test_new5['GarageFinish'] = test_new5['GarageFinish'].fillna(0)
print(test_new5['GarageFinish'].value_counts(),"\n")
# Out:
# 1.0    605
# 2.0    422
# 3.0    352
# 0.0     81
# Name: GarageFinish, dtype: int64
#
# 1.0    625
# 2.0    389
# 3.0    367
# 0.0     78
# Name: GarageFinish, dtype: int64

# %% [markdown]
# ## GarageYrBlt わからないし、他と相関高いのあるし削除

# %%
print(train_new5.corr()['GarageYrBlt'])

# YearBuilt、YearRemodAddと相関高いし削除     
train_new6 = copy.deepcopy(train_new5)
test_new6 = copy.deepcopy(test_new5)

train_new6 = train_new6.drop("GarageYrBlt", axis=1)
test_new6 = test_new6.drop("GarageYrBlt", axis=1)
# Out:
# Id               0.000072
# MSSubClass       0.085072
# LotFrontage      0.046213
# LotArea         -0.024947
# OverallQual      0.547766
# OverallCond     -0.324297
# YearBuilt        0.825667
# YearRemodAdd     0.642277
# MasVnrArea       0.252691
# BsmtFinSF1       0.153484
# BsmtFinSF2      -0.088011
# BsmtUnfSF        0.190708
# TotalBsmtSF      0.322445
# 1stFlrSF         0.233449
# 2ndFlrSF         0.070832
# LowQualFinSF    -0.036363
# GrLivArea        0.231197
# BsmtFullBath     0.124553
# BsmtHalfBath    -0.077464
# FullBath         0.484557
# HalfBath         0.196785
# BedroomAbvGr    -0.064518
# KitchenAbvGr    -0.124411
# TotRmsAbvGrd     0.148112
# Fireplaces       0.046822
# FireplaceQu      0.141497
# GarageYrBlt      1.000000
# GarageFinish     0.525408
# GarageCars       0.588920
# GarageArea       0.564567
# GarageQual       0.308257
# GarageCond       0.262504
# WoodDeckSF       0.224577
# OpenPorchSF      0.228425
# EnclosedPorch   -0.297003
# 3SsnPorch        0.023544
# ScreenPorch     -0.075418
# PoolArea        -0.014501
# Fence           -0.223381
# MiscVal         -0.032417
# MoSold           0.005337
# YrSold          -0.001014
# SalePrice        0.541073
# Name: GarageYrBlt, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## GarageArea、GarageCars 欠損値は0

# %% [markdown]
# * GarageArea、GarageCarsデータの欠陥は1か所のみ(id:2577)で、他のGarage関連の値もNAとなっているので0とする

# %%
train_new7 = copy.deepcopy(train_new6)
test_new7 = copy.deepcopy(test_new6)

train_new7['GarageArea'] = train_new7['GarageArea'].fillna(0)
test_new7['GarageArea'] = test_new7['GarageArea'].fillna(0)
train_new7['GarageCars'] = train_new7['GarageCars'].fillna(0)
test_new7['GarageCars'] = test_new7['GarageCars'].fillna(0)

# %% [markdown]
# ---

# %% [markdown]
# ## GarageType　わからないのでとりあえず、最頻値で

# %%
train_new8 = copy.deepcopy(train_new7)
test_new8 = copy.deepcopy(test_new7)

train_new8['GarageType'] = train_new8['GarageType'].fillna(train_new8['GarageType'].mode()[0])
test_new8['GarageType'] = test_new8['GarageType'].fillna(train_new8['GarageType'].mode()[0])

# %% [markdown]
# ---

# %% [markdown]
# ## BsmQual、BsmCond データの数値化および補間

# %%
print(train_new8['BsmtCond'].value_counts(),"\n")
print(test_new8['BsmtCond'].value_counts(),"\n")
print(train_new8['BsmtQual'].value_counts(),"\n")
print(test_new8['BsmtQual'].value_counts(),"\n")
# Out:
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64
#
# TA    1295
# Fa      59
# Gd      57
# Po       3
# Name: BsmtCond, dtype: int64
#
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64
#
# TA    634
# Gd    591
# Ex    137
# Fa     53
# Name: BsmtQual, dtype: int64

# %%
# GarageQual、GarageCondは6段階評価に直す
train_new9 = copy.deepcopy(train_new8)
test_new9 = copy.deepcopy(test_new8)

train_new9['BsmtCond'] = train_new9['BsmtCond'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})
train_new9['BsmtCond'] = train_new9['BsmtCond'].fillna(0)
print(train_new9['BsmtCond'].value_counts(),"\n")

test_new9['BsmtCond'] = test_new9['BsmtCond'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})
test_new9['BsmtCond'] = test_new9['BsmtCond'].fillna(0)
print(test_new9['BsmtCond'].value_counts(),"\n")

train_new9['BsmtQual'] = train_new9['BsmtQual'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})
train_new9['BsmtQual'] = train_new9['BsmtQual'].fillna(0)
print(train_new9['BsmtQual'].value_counts(),"\n")

test_new9['BsmtQual'] = test_new9['BsmtQual'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})
test_new9['BsmtQual'] = test_new9['BsmtQual'].fillna(0)
print(test_new9['BsmtQual'].value_counts(),"\n")
# Out:
# 3.0    1311
# 4.0      65
# 2.0      45
# 0.0      37
# 1.0       2
# Name: BsmtCond, dtype: int64
#
# 3.0    1295
# 2.0      59
# 4.0      57
# 0.0      45
# 1.0       3
# Name: BsmtCond, dtype: int64
#
# 3.0    649
# 4.0    618
# 5.0    121
# 0.0     37
# 2.0     35
# Name: BsmtQual, dtype: int64
#
# 3.0    634
# 4.0    591
# 5.0    137
# 2.0     53
# 0.0     44
# Name: BsmtQual, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## BsmtExposure、BsmtFinType1、BsmtFinType2 数値化および補間

# %%
print(train_new9['BsmtExposure'].value_counts(),"\n")
print(test_new9['BsmtExposure'].value_counts(),"\n")
print(train_new9['BsmtFinType1'].value_counts(),"\n")
print(test_new9['BsmtFinType1'].value_counts(),"\n")
print(train_new9['BsmtFinType2'].value_counts(),"\n")
print(test_new9['BsmtFinType2'].value_counts(),"\n")
# Out:
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64
#
# No    951
# Av    197
# Gd    142
# Mn    125
# Name: BsmtExposure, dtype: int64
#
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64
#
# GLQ    431
# Unf    421
# ALQ    209
# Rec    155
# BLQ    121
# LwQ     80
# Name: BsmtFinType1, dtype: int64
#
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64
#
# Unf    1237
# Rec      51
# LwQ      41
# BLQ      35
# ALQ      33
# GLQ      20
# Name: BsmtFinType2, dtype: int64

# %%
# BsmtExposureは5段階評価、BsmtFinType1、BsmtFinType2は7段階評価
train_new10 = copy.deepcopy(train_new9)
test_new10 = copy.deepcopy(test_new9)

train_new10['BsmtExposure'] = train_new10['BsmtExposure'].replace({"Gd":4,"Av":3,"Mn":2,"No":1})
train_new10['BsmtExposure'] = train_new10['BsmtExposure'].fillna(0)
print(train_new10['BsmtExposure'].value_counts(),"\n")

test_new10['BsmtExposure'] = test_new10['BsmtExposure'].replace({"Gd":4,"Av":3,"Mn":2,"No":1})
test_new10['BsmtExposure'] = test_new10['BsmtExposure'].fillna(0)
print(test_new10['BsmtExposure'].value_counts(),"\n")

train_new10['BsmtFinType1'] = train_new10['BsmtFinType1'].replace({"GLQ":6,"ALQ":5,"BLQ":4,"Rec":3,"LwQ":2, "Unf":1})
train_new10['BsmtFinType1'] = train_new10['BsmtFinType1'].fillna(0)
print(train_new10['BsmtFinType1'].value_counts(),"\n")

test_new10['BsmtFinType1'] = test_new10['BsmtFinType1'].replace({"GLQ":6,"ALQ":5,"BLQ":4,"Rec":3,"LwQ":2, "Unf":1})
test_new10['BsmtFinType1'] = test_new10['BsmtFinType1'].fillna(0)
print(test_new10['BsmtFinType1'].value_counts(),"\n")

train_new10['BsmtFinType2'] = train_new10['BsmtFinType2'].replace({"GLQ":6,"ALQ":5,"BLQ":4,"Rec":3,"LwQ":2, "Unf":1})
train_new10['BsmtFinType2'] = train_new10['BsmtFinType2'].fillna(0)
print(train_new10['BsmtFinType2'].value_counts(),"\n")

test_new10['BsmtFinType2'] = test_new10['BsmtFinType2'].replace({"GLQ":6,"ALQ":5,"BLQ":4,"Rec":3,"LwQ":2, "Unf":1})
test_new10['BsmtFinType2'] = test_new10['BsmtFinType2'].fillna(0)
print(test_new10['BsmtFinType2'].value_counts(),"\n")
# Out:
# 1.0    953
# 3.0    221
# 4.0    134
# 2.0    114
# 0.0     38
# Name: BsmtExposure, dtype: int64
#
# 1.0    951
# 3.0    197
# 4.0    142
# 2.0    125
# 0.0     44
# Name: BsmtExposure, dtype: int64
#
# 1.0    430
# 6.0    418
# 5.0    220
# 4.0    148
# 3.0    133
# 2.0     74
# 0.0     37
# Name: BsmtFinType1, dtype: int64
#
# 6.0    431
# 1.0    421
# 5.0    209
# 3.0    155
# 4.0    121
# 2.0     80
# 0.0     42
# Name: BsmtFinType1, dtype: int64
#
# 1.0    1256
# 3.0      54
# 2.0      46
# 0.0      38
# 4.0      33
# 5.0      19
# 6.0      14
# Name: BsmtFinType2, dtype: int64
#
# 1.0    1237
# 3.0      51
# 0.0      42
# 2.0      41
# 4.0      35
# 5.0      33
# 6.0      20
# Name: BsmtFinType2, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # BsmtFullBath、BsmtHalfBath、BsmtFinSF1、BsmtFinSF2、BsmtUnfSF、TotalBsmtSF 欠陥値は0

# %% [markdown]
# 地下がないんでしょう

# %%
train_new11 = copy.deepcopy(train_new10)
test_new11 = copy.deepcopy(test_new10)

train_new11['BsmtFullBath'] = train_new11['BsmtFullBath'].fillna(0)
test_new11['BsmtFullBath'] = test_new11['BsmtFullBath'].fillna(0)
train_new11['BsmtHalfBath'] = train_new11['BsmtHalfBath'].fillna(0)
test_new11['BsmtHalfBath'] = test_new11['BsmtHalfBath'].fillna(0)
train_new11['BsmtFinSF1'] = train_new11['BsmtFinSF1'].fillna(0)
test_new11['BsmtFinSF1'] = test_new11['BsmtFinSF1'].fillna(0)
train_new11['BsmtFinSF2'] = train_new11['BsmtFinSF2'].fillna(0)
test_new11['BsmtFinSF2'] = test_new11['BsmtFinSF2'].fillna(0)
train_new11['BsmtUnfSF'] = train_new11['BsmtUnfSF'].fillna(0)
test_new11['BsmtUnfSF'] = test_new11['BsmtUnfSF'].fillna(0)
train_new11['TotalBsmtSF'] = train_new11['TotalBsmtSF'].fillna(0)
test_new11['TotalBsmtSF'] = test_new11['TotalBsmtSF'].fillna(0)

# %% [markdown]
# ---

# %% [markdown]
# # MasVnrType、MasVnrArea

# %%
# MasVnrTypeの欠損値はNone、、MasVnrAreaの欠損値は0
train_new12 = copy.deepcopy(train_new11)
test_new12 = copy.deepcopy(test_new11)

train_new12['MasVnrType'] = train_new12['MasVnrType'].fillna("None")
test_new12['MasVnrType'] = test_new12['MasVnrType'].fillna("None")
train_new12['MasVnrArea'] = train_new12['MasVnrArea'].fillna(0)
test_new12['MasVnrArea'] = test_new12['MasVnrArea'].fillna(0)

# %% [markdown]
# ---

# %% [markdown]
# # MSZoning わからないのでとりあえず、最頻値で(欠損1個しかないし)

# %%
# BsmtExposureは5段階評価、BsmtFinType1、BsmtFinType2は7段階評価
train_new13 = copy.deepcopy(train_new12)
test_new13 = copy.deepcopy(test_new12)

print(train_new13['MSZoning'].value_counts(),"\n")
print(test_new13['MSZoning'].value_counts(),"\n")

train_new13['MSZoning'] = train_new13['MSZoning'].fillna("RL")
test_new13['MSZoning'] = test_new13['MSZoning'].fillna("RL")

print(train_new13['MSZoning'].value_counts(),"\n")
print(test_new13['MSZoning'].value_counts(),"\n")
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
#
# RL         1114
# RM          242
# FV           74
# C (all)      15
# RH           10
# Name: MSZoning, dtype: int64
#
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
#
# RL         1118
# RM          242
# FV           74
# C (all)      15
# RH           10
# Name: MSZoning, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Utilities データが偏りすぎているので使わない

# %%
train_new14 = copy.deepcopy(train_new13)
test_new14 = copy.deepcopy(test_new13)

print(train_new14['Utilities'].value_counts(),"\n")
print(test_new14['Utilities'].value_counts(),"\n")

train_new14 = train_new14.drop("Utilities", axis=1)
test_new14 = test_new14.drop("Utilities", axis=1)
# Out:
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64
#
# AllPub    1457
# Name: Utilities, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Functional 最頻値で問題なさそう(欠損1個しかないし)

# %%
train_new15 = copy.deepcopy(train_new14)
test_new15 = copy.deepcopy(test_new14)

print(train_new15['Functional'].value_counts(),"\n")
print(test_new15['Functional'].value_counts(),"\n")

train_new15['Functional'] = train_new15['Functional'].fillna("Typ")
test_new15['Functional'] = test_new15['Functional'].fillna("Typ")

print(train_new15['Functional'].value_counts(),"\n")
print(test_new15['Functional'].value_counts(),"\n")
# Out:
# Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: Functional, dtype: int64
#
# Typ     1357
# Min2      36
# Min1      34
# Mod       20
# Maj1       5
# Maj2       4
# Sev        1
# Name: Functional, dtype: int64
#
# Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: Functional, dtype: int64
#
# Typ     1359
# Min2      36
# Min1      34
# Mod       20
# Maj1       5
# Maj2       4
# Sev        1
# Name: Functional, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Exterior1st、Exterior2nd わからないのでとりあえず、最頻値で(欠損1個しかないし)

# %%
train_new16 = copy.deepcopy(train_new15)
test_new16 = copy.deepcopy(test_new15)

print(train_new16['Exterior1st'].value_counts(),"\n")
print(test_new16['Exterior1st'].value_counts(),"\n")

train_new16['Exterior1st'] = train_new16['Exterior1st'].fillna("VinylSd")
test_new16['Exterior1st'] = test_new16['Exterior1st'].fillna("VinylSd")

print(train_new16['Exterior1st'].value_counts(),"\n")
print(test_new16['Exterior1st'].value_counts(),"\n")

print(train_new16['Exterior2nd'].value_counts(),"\n")
print(test_new16['Exterior2nd'].value_counts(),"\n")

train_new16['Exterior2nd'] = train_new16['Exterior2nd'].fillna("VinylSd")
test_new16['Exterior2nd'] = test_new16['Exterior2nd'].fillna("VinylSd")

print(train_new16['Exterior2nd'].value_counts(),"\n")
print(test_new16['Exterior2nd'].value_counts(),"\n")
# Out:
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# Stone        2
# BrkComm      2
# AsphShn      1
# CBlock       1
# ImStucc      1
# Name: Exterior1st, dtype: int64
#
# VinylSd    510
# MetalSd    230
# HdBoard    220
# Wd Sdng    205
# Plywood    113
# CemntBd     65
# BrkFace     37
# WdShing     30
# AsbShng     24
# Stucco      18
# BrkComm      4
# AsphShn      1
# CBlock       1
# Name: Exterior1st, dtype: int64
#
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# Stone        2
# BrkComm      2
# AsphShn      1
# CBlock       1
# ImStucc      1
# Name: Exterior1st, dtype: int64
#
# VinylSd    511
# MetalSd    230
# HdBoard    220
# Wd Sdng    205
# Plywood    113
# CemntBd     65
# BrkFace     37
# WdShing     30
# AsbShng     24
# Stucco      18
# BrkComm      4
# AsphShn      1
# CBlock       1
# Name: Exterior1st, dtype: int64
#
# VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# CmentBd     60
# Wd Shng     38
# Stucco      26
# BrkFace     25
# AsbShng     20
# ImStucc     10
# Brk Cmn      7
# Stone        5
# AsphShn      3
# Other        1
# CBlock       1
# Name: Exterior2nd, dtype: int64
#
# VinylSd    510
# MetalSd    233
# HdBoard    199
# Wd Sdng    194
# Plywood    128
# CmentBd     66
# Wd Shng     43
# BrkFace     22
# Stucco      21
# AsbShng     18
# Brk Cmn     15
# ImStucc      5
# CBlock       2
# AsphShn      1
# Stone        1
# Name: Exterior2nd, dtype: int64
#
# VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# CmentBd     60
# Wd Shng     38
# Stucco      26
# BrkFace     25
# AsbShng     20
# ImStucc     10
# Brk Cmn      7
# Stone        5
# AsphShn      3
# Other        1
# CBlock       1
# Name: Exterior2nd, dtype: int64
#
# VinylSd    511
# MetalSd    233
# HdBoard    199
# Wd Sdng    194
# Plywood    128
# CmentBd     66
# Wd Shng     43
# BrkFace     22
# Stucco      21
# AsbShng     18
# Brk Cmn     15
# ImStucc      5
# CBlock       2
# AsphShn      1
# Stone        1
# Name: Exterior2nd, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # KitchenQual 最頻値で(欠損1個しかないし)

# %%
# kitchenの項目はNAがないので、kitchenがないわけではないので0ではない

train_new17 = copy.deepcopy(train_new16)
test_new17 = copy.deepcopy(test_new16)

print(train_new17['KitchenQual'].value_counts(),"\n")
print(test_new17['KitchenQual'].value_counts(),"\n")

# Poはない
train_new17['KitchenQual'] = train_new17['KitchenQual'].replace({"Ex":4,"Gd":3,"TA":2,"Fa":1})
train_new17['KitchenQual'] = train_new17['KitchenQual'].fillna(2)
test_new17['KitchenQual'] = test_new17['KitchenQual'].replace({"Ex":4,"Gd":3,"TA":2,"Fa":1})
test_new17['KitchenQual'] = test_new17['KitchenQual'].fillna(2)
print(train_new17['KitchenQual'].value_counts(),"\n")
print(test_new17['KitchenQual'].value_counts(),"\n")
# Out:
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: KitchenQual, dtype: int64
#
# TA    757
# Gd    565
# Ex    105
# Fa     31
# Name: KitchenQual, dtype: int64
#
# 2    735
# 3    586
# 4    100
# 1     39
# Name: KitchenQual, dtype: int64
#
# 2.0    758
# 3.0    565
# 4.0    105
# 1.0     31
# Name: KitchenQual, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # SaleType 最頻値で(欠損1個しかないし)

# %%
train_new18 = copy.deepcopy(train_new17)
test_new18 = copy.deepcopy(test_new17)

print(train_new18['SaleType'].value_counts(),"\n")
print(test_new18['SaleType'].value_counts(),"\n")

train_new18['SaleType'] = train_new16['SaleType'].fillna("WD")
test_new18['SaleType'] = test_new16['SaleType'].fillna("WD")

print(train_new18['SaleType'].value_counts(),"\n")
print(test_new18['SaleType'].value_counts(),"\n")
# Out:
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLI       5
# ConLw       5
# CWD         4
# Oth         3
# Con         2
# Name: SaleType, dtype: int64
#
# WD       1258
# New       117
# COD        44
# ConLD      17
# CWD         8
# ConLI       4
# Oth         4
# ConLw       3
# Con         3
# Name: SaleType, dtype: int64
#
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLI       5
# ConLw       5
# CWD         4
# Oth         3
# Con         2
# Name: SaleType, dtype: int64
#
# WD       1259
# New       117
# COD        44
# ConLD      17
# CWD         8
# ConLI       4
# Oth         4
# ConLw       3
# Con         3
# Name: SaleType, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Electrical

# %%
train_new19 = copy.deepcopy(train_new18)
test_new19 = copy.deepcopy(test_new18)

print(train_new19['Electrical'].value_counts(),"\n")
print(test_new19['Electrical'].value_counts(),"\n")

train_new19['Electrical'] = train_new19['Electrical'].fillna("SBrkr")
test_new19['Electrical'] = test_new19['Electrical'].fillna("SBrkr")

print(train_new19['Electrical'].value_counts(),"\n")
print(test_new19['Electrical'].value_counts(),"\n")
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64
#
# SBrkr    1337
# FuseA      94
# FuseF      23
# FuseP       5
# Name: Electrical, dtype: int64
#
# SBrkr    1335
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64
#
# SBrkr    1337
# FuseA      94
# FuseF      23
# FuseP       5
# Name: Electrical, dtype: int64

# %% [markdown]
# ---
# ここまでの確認

# %%
df_null_rate_train2 = pd.DataFrame(train_new19.isnull().sum()/len(train))
df_null_rate_test2 = pd.DataFrame(test_new19.isnull().sum()/len(test))
df_null_rate2 = pd.concat([df_null_rate_test2[df_null_rate_test2.values>0], df_null_rate_train2[df_null_rate_train2.values>0]], axis=1, sort=False).fillna(0)
df_null_rate2.columns = ['test null rate', 'train null rate']
print(df_null_rate2.sort_values('test null rate', ascending=False))
# Out:
# Empty DataFrame
# Columns: [test null rate, train null rate]
# Index: []

# %% [markdown]
# # 欠陥値なし

# %% [markdown]
# ---

# %% [markdown]
# # その他の欠陥なしデータについて

# %%
chcek_train = df_null_rate_train[df_null_rate_train[[0]][0]==0].T.columns.tolist()
chcek_test = df_null_rate_train[df_null_rate_train[[0]][0]==0].T.columns.tolist()
check_list = chcek_train + chcek_test
non_NA = [x for x in set(check_list) if check_list.count(x) > 1]
print(sorted(non_NA))
# Out:
# ['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'BedroomAbvGr', 'BldgType', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtFullBath', 'BsmtHalfBath', 'BsmtUnfSF', 'CentralAir', 'Condition1', 'Condition2', 'EnclosedPorch', 'ExterCond', 'ExterQual', 'Exterior1st', 'Exterior2nd', 'Fireplaces', 'Foundation', 'FullBath', 'Functional', 'GarageArea', 'GarageCars', 'GrLivArea', 'HalfBath', 'Heating', 'HeatingQC', 'HouseStyle', 'Id', 'KitchenAbvGr', 'KitchenQual', 'LandContour', 'LandSlope', 'LotArea', 'LotConfig', 'LotShape', 'LowQualFinSF', 'MSSubClass', 'MSZoning', 'MiscVal', 'MoSold', 'Neighborhood', 'OpenPorchSF', 'OverallCond', 'OverallQual', 'PavedDrive', 'PoolArea', 'RoofMatl', 'RoofStyle', 'SaleCondition', 'SalePrice', 'SaleType', 'ScreenPorch', 'Street', 'TotRmsAbvGrd', 'TotalBsmtSF', 'Utilities', 'WoodDeckSF', 'YearBuilt', 'YearRemodAdd', 'YrSold']

# %%
# print(train_new19['Utilities'].value_counts(),"\n")
print(test_new19['BldgType'].value_counts(),"\n")
# Out:
# 1Fam      1205
# TwnhsE     113
# Duplex      57
# Twnhs       53
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
# そのまま　
# 1stFlrSF、2ndFlrSF、3SsnPorch、BedroomAbvGr、BsmtFinSF1、BsmtFinSF2、BsmtFullBath、BsmtHalfBath、BsmtUnfSF、EnclosedPorch、Exterior1st,FullBath、
# Exterior2nd、Fireplaces、GarageArea、GarageCars、GrLivArea、HalfBath、KitchenAbvGr、KitchenQual、LotArea、LowQualFinSF、MiscVal、MoSold、OpenPorchSF、OverallCond,
# OverallQual、PoolArea、TotRmsAbvGrd、TotalBsmtSF、WoodDeckSF、

# %%
# 年度 
# YearBuilt、YearRemodAdd、YrSold

train_new20 = copy.deepcopy(train_new19)
test_new20 = copy.deepcopy(test_new19)

train_new20['YearBuilt'] = train_new20['YearBuilt']- int(train_new20['YearBuilt'].mean())
test_new20['YearBuilt'] = test_new20['YearBuilt']- int(test_new20['YearBuilt'].mean())
train_new20['YearRemodAdd'] = train_new20['YearRemodAdd']- int(train_new20['YearRemodAdd'].mean())
test_new20['YearRemodAdd'] = test_new20['YearRemodAdd']- int(test_new20['YearRemodAdd'].mean())
train_new20['YrSold'] = train_new20['YrSold']- int(train_new20['YrSold'].mean())
test_new20['YrSold'] = test_new20['YrSold']- int(test_new20['YrSold'].mean())

# %%
# 文字列(ダミー変数)に変更　BldgType、CentralAir、Condition1、Condition2、Foundation、Functional、Heating、HouseStyle、LandContour、LandSlope、Neighborhood
# LotConfig、LotShape、MSZoning、PavedDrive、RoofMatl、RoofStyle、SaleCondition、SaleType、Street、
# なぜか数値　MSSubClass

train_new21 = copy.deepcopy(train_new20)
test_new21 = copy.deepcopy(test_new20)

dummies_list = ["BldgType","CentralAir","Condition1","Condition2","Foundation","Functional","Heating","HouseStyle","LandContour","LandSlope",
                "Neighborhood","LotConfig","LotShape","MSZoning","PavedDrive","RoofMatl","RoofStyle","SaleCondition","SaleType","Street",
                "Exterior1st", "Exterior2nd", "MasVnrType","Electrical", "GarageType" ]

for name in dummies_list:
    train_new21 = pd.concat([train_new21, pd.get_dummies(train_new21[[name]])], axis=1)
    test_new21 = pd.concat([test_new21, pd.get_dummies(test_new21[[name]])], axis=1)
    train_new21 = train_new21.drop(name, axis=1)
    

train_new21 = pd.concat([train_new21,pd.get_dummies(train_new2[['MSSubClass']].astype(str))], axis=1)
test_new21 = pd.concat([test_new21,pd.get_dummies(test_new2[['MSSubClass']].astype(str))], axis=1)
train_new21 = train_new21.drop('MSSubClass', axis=1)

# %%
# 数値に変更ExterCond、ExterQual、HeatingQC、、、
train_new22 = copy.deepcopy(train_new21)
test_new22 = copy.deepcopy(test_new21)

train_new22['ExterCond'] = train_new22['ExterCond'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})
test_new22['ExterCond'] = test_new22['ExterCond'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})
train_new22['ExterQual'] = train_new22['ExterQual'].replace({"Ex":4,"Gd":3,"TA":2,"Fa":1})
test_new22['ExterQual'] = test_new22['ExterQual'].replace({"Ex":4,"Gd":3,"TA":2,"Fa":1})
train_new22['HeatingQC'] = train_new22['HeatingQC'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})
test_new22['HeatingQC'] = test_new22['HeatingQC'].replace({"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1})

# %%
# 削除する　ID
train_new23 = copy.deepcopy(train_new22)
test_new23 = copy.deepcopy(test_new22)

train_new23 = train_new23.drop("Id", axis = 1)
test_new23 = test_new23.drop("Id", axis = 1)

# %% [markdown]
# ---

# %%
train_new24 = copy.deepcopy(train_new23)
test_new24 = copy.deepcopy(test_new23)

y_train = train_new24.SalePrice.values
x_train = train_new24.drop(['SalePrice'], axis=1)

print(len(y_train), x_train.shape)
# Out:
# 1460 (1460, 240)

# %% [markdown]
# # 前処理終了

# %% [markdown]
# ---

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb
import numpy as np
import optuna
# Out:
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
def result(model):
    kfold = KFold(n_splits=5, shuffle=True, random_state=0)
    scores_msq = cross_val_score(model, x_train, y_train, cv = kfold, scoring='neg_mean_squared_error')
    
    scores = []
    for score_msq in scores_msq:
        scores.append(np.sqrt(-score_msq))
        
    return scores

# %% [markdown]
# ---

# %%
def objective(trial):
    '''
    trial:set of hyperparameter    
    '''
    # hypyer param
    max_depth = trial.suggest_int('max_depth', 3, 20) # 深すぎると過学習になるかも...
    n_estimators = trial.suggest_int('n_estimators', 50, 10000) # しっかりやるなら100以上
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'auto', 'log2'])
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 100)
    min_samples_split = trial.suggest_int('min_samples_split', 1, 100)
    random_state =  trial.suggest_int('random_state', 1, 10)
    
    
    # model
    model  = make_pipeline(RobustScaler(),
                                GradientBoostingRegressor(
                                n_estimators= n_estimators, 
                                learning_rate=0.1,
                                max_depth=max_depth, 
                                max_features=max_features,
                                min_samples_leaf=min_samples_leaf, 
                                min_samples_split= min_samples_split, 
                                loss='huber', 
                                random_state =random_state)
                             )

    scores = result(model)
    score =  np.mean(scores)
    
    return score

# %%
study = optuna.create_study()
 
# https://optuna.readthedocs.io/en/stable/reference/study.html#optuna.study.Study.optimize
study.optimize(func=objective, # 実行する関数
               n_trials=500, # 試行回数
               timeout=None, # 与えられた秒数後に学習を中止します。default=None
               n_jobs=8 # 並列実行するjob数
              )
# Out:
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [W 2019-09-07 16:35:12,421] Setting status of trial#3 as TrialState.FAIL because of the following error: ValueError('min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1')
# Traceback (most recent call last):
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/optuna/study.py", line 399, in _run_trial
#     result = func(trial)
#   File "<ipython-input-50-ec413d07ab0f>", line 27, in objective
#     scores = result(model)
#   File "<ipython-input-49-e08cda819517>", line 3, in result
#     scores_msq = cross_val_score(model, x_train, y_train, cv = kfold, scoring='neg_mean_squared_error')
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 342, in cross_val_score
#     pre_dispatch=pre_dispatch)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 206, in cross_validate
#     for train, test in cv.split(X, y, groups))
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 779, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 625, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 588, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 111, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 332, in __init__
#     self.results = batch()
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 131, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 131, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 458, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/pipeline.py", line 250, in fit
#     self._final_estimator.fit(Xt, y, **fit_params)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py", line 1034, in fit
#     begin_at_stage, monitor, X_idx_sorted)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py", line 1089, in _fit_stages
#     X_csc, X_csr)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py", line 788, in _fit_stage
#     check_input=False, X_idx_sorted=X_idx_sorted)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/tree/tree.py", line 1124, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/tree/tree.py", line 194, in fit
#     % self.min_samples_split)
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 16:43:00,537] Finished trial#2 resulted in value: 0.12714622199083964. Current best value is 0.12714622199083964 with parameters: {'max_depth': 3, 'n_estimators': 3712, 'max_features': 'sqrt', 'min_samples_leaf': 21, 'min_samples_split': 29, 'random_state': 3}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 16:45:49,057] Finished trial#6 resulted in value: 0.13093630400864084. Current best value is 0.12714622199083964 with parameters: {'max_depth': 3, 'n_estimators': 3712, 'max_features': 'sqrt', 'min_samples_leaf': 21, 'min_samples_split': 29, 'random_state': 3}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 16:46:05,016] Finished trial#4 resulted in value: 0.13021446864495778. Current best value is 0.12714622199083964 with parameters: {'max_depth': 3, 'n_estimators': 3712, 'max_features': 'sqrt', 'min_samples_leaf': 21, 'min_samples_split': 29, 'random_state': 3}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 16:50:02,735] Finished trial#5 resulted in value: 0.13373658514582767. Current best value is 0.12714622199083964 with parameters: {'max_depth': 3, 'n_estimators': 3712, 'max_features': 'sqrt', 'min_samples_leaf': 21, 'min_samples_split': 29, 'random_state': 3}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 16:51:11,324] Finished trial#8 resulted in value: 0.12931063791906813. Current best value is 0.12714622199083964 with parameters: {'max_depth': 3, 'n_estimators': 3712, 'max_features': 'sqrt', 'min_samples_leaf': 21, 'min_samples_split': 29, 'random_state': 3}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 16:51:28,649] Finished trial#11 resulted in value: 0.13244425575430147. Current best value is 0.12714622199083964 with parameters: {'max_depth': 3, 'n_estimators': 3712, 'max_features': 'sqrt', 'min_samples_leaf': 21, 'min_samples_split': 29, 'random_state': 3}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 16:52:01,964] Finished trial#0 resulted in value: 0.13094993454716367. Current best value is 0.12714622199083964 with parameters: {'max_depth': 3, 'n_estimators': 3712, 'max_features': 'sqrt', 'min_samples_leaf': 21, 'min_samples_split': 29, 'random_state': 3}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 16:53:21,878] Finished trial#14 resulted in value: 0.12827300943968617. Current best value is 0.12714622199083964 with parameters: {'max_depth': 3, 'n_estimators': 3712, 'max_features': 'sqrt', 'min_samples_leaf': 21, 'min_samples_split': 29, 'random_state': 3}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 16:55:10,855] Finished trial#1 resulted in value: 0.12925296808604933. Current best value is 0.12714622199083964 with parameters: {'max_depth': 3, 'n_estimators': 3712, 'max_features': 'sqrt', 'min_samples_leaf': 21, 'min_samples_split': 29, 'random_state': 3}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 16:57:09,902] Finished trial#7 resulted in value: 0.13605359513851975. Current best value is 0.12714622199083964 with parameters: {'max_depth': 3, 'n_estimators': 3712, 'max_features': 'sqrt', 'min_samples_leaf': 21, 'min_samples_split': 29, 'random_state': 3}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 16:57:58,140] Finished trial#12 resulted in value: 0.13130594821911096. Current best value is 0.12714622199083964 with parameters: {'max_depth': 3, 'n_estimators': 3712, 'max_features': 'sqrt', 'min_samples_leaf': 21, 'min_samples_split': 29, 'random_state': 3}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 16:58:55,434] Finished trial#13 resulted in value: 0.1273932204809865. Current best value is 0.12714622199083964 with parameters: {'max_depth': 3, 'n_estimators': 3712, 'max_features': 'sqrt', 'min_samples_leaf': 21, 'min_samples_split': 29, 'random_state': 3}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [W 2019-09-07 16:58:55,566] Setting status of trial#20 as TrialState.FAIL because of the following error: ValueError('min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1')
# Traceback (most recent call last):
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/optuna/study.py", line 399, in _run_trial
#     result = func(trial)
#   File "<ipython-input-50-ec413d07ab0f>", line 27, in objective
#     scores = result(model)
#   File "<ipython-input-49-e08cda819517>", line 3, in result
#     scores_msq = cross_val_score(model, x_train, y_train, cv = kfold, scoring='neg_mean_squared_error')
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 342, in cross_val_score
#     pre_dispatch=pre_dispatch)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 206, in cross_validate
#     for train, test in cv.split(X, y, groups))
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 779, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 625, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 588, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 111, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 332, in __init__
#     self.results = batch()
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 131, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 131, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 458, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/pipeline.py", line 250, in fit
#     self._final_estimator.fit(Xt, y, **fit_params)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py", line 1034, in fit
#     begin_at_stage, monitor, X_idx_sorted)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py", line 1089, in _fit_stages
#     X_csc, X_csr)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py", line 788, in _fit_stage
#     check_input=False, X_idx_sorted=X_idx_sorted)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/tree/tree.py", line 1124, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/tree/tree.py", line 194, in fit
#     % self.min_samples_split)
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [W 2019-09-07 16:58:55,899] Setting status of trial#21 as TrialState.FAIL because of the following error: ValueError('min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1')
# Traceback (most recent call last):
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/optuna/study.py", line 399, in _run_trial
#     result = func(trial)
#   File "<ipython-input-50-ec413d07ab0f>", line 27, in objective
#     scores = result(model)
#   File "<ipython-input-49-e08cda819517>", line 3, in result
#     scores_msq = cross_val_score(model, x_train, y_train, cv = kfold, scoring='neg_mean_squared_error')
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 342, in cross_val_score
#     pre_dispatch=pre_dispatch)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 206, in cross_validate
#     for train, test in cv.split(X, y, groups))
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 779, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 625, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 588, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 111, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 332, in __init__
#     self.results = batch()
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 131, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 131, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 458, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/pipeline.py", line 250, in fit
#     self._final_estimator.fit(Xt, y, **fit_params)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py", line 1034, in fit
#     begin_at_stage, monitor, X_idx_sorted)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py", line 1089, in _fit_stages
#     X_csc, X_csr)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py", line 788, in _fit_stage
#     check_input=False, X_idx_sorted=X_idx_sorted)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/tree/tree.py", line 1124, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/tree/tree.py", line 194, in fit
#     % self.min_samples_split)
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:00:50,071] Finished trial#22 resulted in value: 0.12504531294816829. Current best value is 0.12504531294816829 with parameters: {'max_depth': 3, 'n_estimators': 670, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 62, 'random_state': 7}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:01:19,824] Finished trial#15 resulted in value: 0.13618715646525203. Current best value is 0.12504531294816829 with parameters: {'max_depth': 3, 'n_estimators': 670, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 62, 'random_state': 7}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:01:22,700] Finished trial#18 resulted in value: 0.12352624701140531. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:01:38,376] Finished trial#23 resulted in value: 0.12647326885454996. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:04:08,701] Finished trial#19 resulted in value: 0.1262866861906019. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:05:39,138] Finished trial#26 resulted in value: 0.12861188481217942. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:08:08,527] Finished trial#24 resulted in value: 0.12851507507060453. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:08:56,063] Finished trial#25 resulted in value: 0.13100837556607786. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:09:57,034] Finished trial#27 resulted in value: 0.13084751996761057. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:10:20,356] Finished trial#10 resulted in value: 0.13134620140555112. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:11:48,501] Finished trial#28 resulted in value: 0.13080108476250923. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:11:54,624] Finished trial#33 resulted in value: 0.13409562410401796. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:15:55,999] Finished trial#32 resulted in value: 0.12688889593655997. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:17:40,539] Finished trial#9 resulted in value: 0.13968105270479203. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:18:22,694] Finished trial#17 resulted in value: 0.13884408065462434. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:20:31,966] Finished trial#16 resulted in value: 0.13673646559197372. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:21:37,016] Finished trial#37 resulted in value: 0.125796960675205. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:23:21,320] Finished trial#34 resulted in value: 0.12836938467335707. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:24:15,446] Finished trial#30 resulted in value: 0.13064251329338403. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:24:28,129] Finished trial#29 resulted in value: 0.13169229863382811. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:24:40,887] Finished trial#38 resulted in value: 0.12747118946708055. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:25:10,948] Finished trial#39 resulted in value: 0.12875749365163824. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:26:14,569] Finished trial#31 resulted in value: 0.13025758341064708. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:29:56,479] Finished trial#40 resulted in value: 0.12931232011374105. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:31:00,077] Finished trial#41 resulted in value: 0.13163877512030472. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:32:33,261] Finished trial#35 resulted in value: 0.12906257578534394. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:35:39,539] Finished trial#43 resulted in value: 0.1274916512995112. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:36:02,309] Finished trial#36 resulted in value: 0.1266147004743861. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:37:34,600] Finished trial#50 resulted in value: 0.12710563260473423. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:41:25,943] Finished trial#42 resulted in value: 0.12654849059409387. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:42:05,851] Finished trial#51 resulted in value: 0.12919814518981593. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:43:13,194] Finished trial#44 resulted in value: 0.12919737747017335. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:43:18,795] Finished trial#46 resulted in value: 0.1297270028409844. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:43:48,030] Finished trial#45 resulted in value: 0.12792292506097144. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:45:54,546] Finished trial#47 resulted in value: 0.1304561506014528. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:46:16,448] Finished trial#48 resulted in value: 0.1296617220676253. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:50:11,718] Finished trial#49 resulted in value: 0.1291334107620406. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:52:06,894] Finished trial#52 resulted in value: 0.12841376192888082. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:56:26,630] Finished trial#54 resulted in value: 0.12993877300611192. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:56:43,742] Finished trial#56 resulted in value: 0.12993877300611192. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:58:17,167] Finished trial#53 resulted in value: 0.12993877300611192. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:58:48,785] Finished trial#55 resulted in value: 0.12975817726453615. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:59:10,358] Finished trial#61 resulted in value: 0.12818847532559574. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:59:15,003] Finished trial#58 resulted in value: 0.1283718768766572. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 17:59:40,281] Finished trial#59 resulted in value: 0.1276923913472306. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 18:00:12,193] Finished trial#57 resulted in value: 0.1299049410167729. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 18:00:32,546] Finished trial#67 resulted in value: 0.13142855139534362. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 18:00:48,850] Finished trial#64 resulted in value: 0.12796597650862462. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 18:00:56,564] Finished trial#63 resulted in value: 0.12909339483186208. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 18:04:28,451] Finished trial#65 resulted in value: 0.13269589469922644. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 18:05:12,832] Finished trial#71 resulted in value: 0.13026754442757407. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 18:05:48,457] Finished trial#70 resulted in value: 0.12552270240366986. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 18:06:18,196] Finished trial#72 resulted in value: 0.12553502633091768. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-07 18:06:20,269] Finished trial#68 resulted in value: 0.12925613981833167. Current best value is 0.12352624701140531 with parameters: {'max_depth': 3, 'n_estimators': 3461, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 4}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# ...
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:32:13,551] Finished trial#459 resulted in value: 0.12607973373549977. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:33:39,648] Finished trial#467 resulted in value: 0.12944389530790962. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:33:53,694] Finished trial#472 resulted in value: 0.1280457324367058. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:35:57,884] Finished trial#465 resulted in value: 0.12568265691150754. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:36:17,659] Finished trial#466 resulted in value: 0.12479039811206757. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:36:37,764] Finished trial#470 resulted in value: 0.12761140124729814. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:36:46,253] Finished trial#478 resulted in value: 0.12854219527473637. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:38:48,564] Finished trial#475 resulted in value: 0.1285193595674323. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:42:04,634] Finished trial#471 resulted in value: 0.1256183365141427. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:46:25,293] Finished trial#477 resulted in value: 0.12546241165427038. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:46:55,716] Finished trial#474 resulted in value: 0.129490724776894. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:47:36,296] Finished trial#473 resulted in value: 0.12975847810583424. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:49:10,833] Finished trial#479 resulted in value: 0.12713901162023863. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:49:30,456] Finished trial#476 resulted in value: 0.12624999152037977. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:51:21,237] Finished trial#480 resulted in value: 0.13007594481997936. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:51:54,123] Finished trial#481 resulted in value: 0.13000311414375468. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:54:45,253] Finished trial#484 resulted in value: 0.1294641341764532. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:54:47,729] Finished trial#482 resulted in value: 0.12845193424680362. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:56:31,090] Finished trial#486 resulted in value: 0.12953553187299988. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:57:20,258] Finished trial#487 resulted in value: 0.1295028851905984. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:58:37,888] Finished trial#488 resulted in value: 0.12773393159313534. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:59:09,992] Finished trial#485 resulted in value: 0.12861521073111853. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:59:31,526] Finished trial#489 resulted in value: 0.1285916582176004. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 01:59:37,067] Finished trial#483 resulted in value: 0.1281773462963766. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 02:01:43,988] Finished trial#492 resulted in value: 0.12809865442205018. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 02:02:30,433] Finished trial#491 resulted in value: 0.12538702173263622. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   **self._backend_args)
# [I 2019-09-08 02:03:35,920] Finished trial#490 resulted in value: 0.12780415550633087. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# [I 2019-09-08 02:06:53,341] Finished trial#493 resulted in value: 0.12662811725557996. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# [I 2019-09-08 02:07:20,250] Finished trial#494 resulted in value: 0.1263366195522086. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# [I 2019-09-08 02:08:11,887] Finished trial#497 resulted in value: 0.12612762954388612. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# [I 2019-09-08 02:08:28,183] Finished trial#496 resulted in value: 0.126994329997702. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# [I 2019-09-08 02:09:01,649] Finished trial#495 resulted in value: 0.1283850756049657. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# [I 2019-09-08 02:09:12,702] Finished trial#498 resulted in value: 0.1260938230053325. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
# [I 2019-09-08 02:10:52,279] Finished trial#499 resulted in value: 0.13094049658653548. Current best value is 0.1192727088047733 with parameters: {'max_depth': 5, 'n_estimators': 5105, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 83, 'random_state': 2}.
